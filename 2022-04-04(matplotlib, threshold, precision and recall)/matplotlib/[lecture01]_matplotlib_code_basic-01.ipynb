# %% [markdown]
# https://wikidocs.net/92071

# %%
# 예제1

# %%
import matplotlib.pyplot as plt

plt.plot([1,2,3,4]) #함수에 하나의 숫자 리스트를 입력함으로써 아래와 같은 그래프가 그려짐
plt.show()

# %%
#예제2

# %%
plt.plot([1,2,3,4],[1,4,9,16]) #X값의 경우 1,2,3,4
                               #y값의 경우 1,4,9,16
plt.show()

# %% [markdown]
# ### 스타일 지정하기

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
plt.plot([1,2,3,4],[1,4,9,16],'ro')
plt.axis([0,6,0,20])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# x,y 값 인자에 대해 선의 색상과 형태를 지정하는 포맷 문자열(format string)을 세 번째 인자에 입력할 수 있다.

# %% [markdown]
# * 포맷 문자열 'ro'는 빨간색 ('red)의 동그라미 모양('o)을 의미
# * 예를 들어 'b-'는 파란색('blue')의 실선('-')을 의미

# %% [markdown]
# ## 여러 개의 그래프 그리기

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
import pandas as pd

# 200ms 간격으로 균일하게 샘플된 시간
t = np.arange(0.,5.,0.2)

#red dash and blue square, green triangle
plt.plot(t,t,'r--',t,t**2,'bs',t,t**3,'g^')

# %%
# Matplotlib에서는 일반적으로 ndarray를 활용
# 모든 시퀀스는 내부적으로 Numpy어레이로 변환
