# %%
income3 = (1064*0.967)
print('4월 수입:',income)

# %%
cost = (-400-35-50-50-200-20)
print('비용:', cost)

income3 + cost

# %%
income4 = (937.5*0.967)
income4 + cost

# %%
# !pip install nltk

# %%
# !pip install keras

# %%
from nltk.tokenize import word_tokenize
from nltk.tokenize import WordPunctTokenizer
from tensorflow.keras.preprocessing.text import text_to_word_sequence

# %%
 import nltk
 nltk.download('punkt')

# %% [markdown]
# 1. 단어 토큰화(Word Tokenization)

# %%
print('Tokenize1 :', word_tokenize("Don't be fooled by the dark sounding name, Mr. Jone's Orphanage is as cheery as cheery goes for a pastry shop."))

# %%
print('Tokenize2 :', WordPunctTokenizer().tokenize("Don't be fooled by the dark sounding name, Mr. Jone's Orphanage is as cheery as cheery goes for a pastry shop."))

# %%
print('Tokenize3 :', text_to_word_sequence("Don't be fooled by the dark sounding name, Mr. Jone's Orphanage is as cheery as cheery goes for a pastry shop."))

# %% [markdown]
# 2. 토큰화시 고려사항

# %%
from nltk.tokenize import TreebankWordTokenizer

tokenizer = TreebankWordTokenizer()

text = "Starting a home-based restaurant may be an ideal. it doesn`t have a food chain \
 or restaurant of their own."

print('트리뱅크 워드토크나이저 :', tokenizer.tokenize(text))

# %% [markdown]
# 정규표현식 활용

# %%
import re
text = 'I was wondering if anyone out there could enlighten me on his car.'

# %%
# 길이가 1~2인 단어들을 정규 표현식을 활용하여 삭제
stopword = re.compile(r'\W*\b\w{1,2}\b')
print(stopword.sub('', text))

# %% [markdown]
# 03) 어간 추출(stemming) and 표제어 추출(Lemmatization)

# %%
import nltk
nltk.download('wordnet')

# %%
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()

words = ['policy', 'doing', 'organization', 'have', 'going', 'love', 'lives', 'fly', 'dies', 'watched', 'has', 'starting']

print('표제어 추출 전 :',words)
print('표제어 추출 후 :',[lemmatizer.lemmatize(word) for word in words])

# %%
lemmatizer.lemmatize('dies','v')

# %%
lemmatizer.lemmatize('watched','v')

# %%
lemmatizer.lemmatize('has','v')

# %%
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize

stemmer = PorterStemmer()

sentence = "This was not the map we found in Billy Bones's chest, but an accurate copy, complete in all things--names and heights and soundings--with the single exception of the red crosses and the written notes."

tokenized_sentence = word_tokenize(sentence)

# %%
print('어간 추출 전:', tokenized_sentence)
print('어간 추출 후:', [stemmer.stem(word) for word in tokenized_sentence])

# %%
words = ['formalize', 'allowance', 'electricical']

print('stemming 전 :', words)
print('stemming 후 :', [stemmer.stem(word) for word in words])

# %% [markdown]
# 04) 불용어(Stopword)

# %%
# !pip install konlpy

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from konlpy.tag import Okt

# %%
import nltk
nltk.download('stopwords')

# %%
stop_words_list = stopwords.words('english')
print('불용어 개수 :', len(stop_words_list))
print('불용어 10개 출력 :',stop_words_list[:10])

# %% [markdown]
# 2. NLTK를 통해서 불용어 제거

# %%
example = 'Family is not an important thing. It`s everything.'
stop_words = set(stopwords.words('english'))

word_tokens = word_tokenize(example)
word_tokens

# %%
result = []

for word in word_tokens:
    if word not in stop_words:
        result.append(word)


result

# %%
okt = Okt()

example = "고기를 아무렇게나 구우려고 하면 안 돼. 고기라고 다 같은 게 아니거든. 예컨대 삼겹살을 구울 때는 중요한 게 있지."
stop_words = "를 아무렇게나 구 우려 고 안 돼 같은 게 구울 때 는" 

stop_words = set(stop_words.split(' '))
word_tokens = okt.morphs(example)

result = [word for word in word_tokens if not word in stop_words]
result

# %%
import re

# %% [markdown]
# 1) .기호

# %%
r = re.compile('a.c')
r.search('kkk')

# %%
r.search('abc')

# %% [markdown]
# .은 어떤 문자로도 인식될 수 있기 때문에 abc라는 문자열은 a.c라는 정규 표현식 패턴으로 매치됨

# %% [markdown]
# 2) ?기호

# %%
r = re.compile('ab?c')
r.search('abbc')

# %%
r.search('abc')

# %%
r.search('ac')

# %% [markdown]
# 정수 인코딩

# %%
from nltk.tokenize import sent_tokenize
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# %%
raw_text = "A barber is a person. a barber is good person. a barber is huge person. he Knew A Secret! The Secret He Kept is huge secret. Huge secret. His barber kept his word. a barber kept his word. His barber kept his secret. But keeping and keeping such a huge secret to himself was driving the barber crazy. the barber went up a huge mountain."

# %%
# 문장 토큰화
sentences = sent_tokenize(raw_text)
print(sentences)

# %%
vocab = {}
preprocessed_sentences = []
stop_words = set(stopwords.words('english'))

for sentence in sentences:
    # 단어 토큰화
    tokenized_sentence = word_tokenize(sentence)
    result = []

    for word in tokenized_sentence:
        word = word.lower() # 모든 단어를 lower하게 바꿔서 단어의 개수를 줄임
        if word not in stop_words:
            if len(word)>2:
                result.append(word)
                if word not in vocab:
                    vocab[word] = 0
                vocab[word] += 1
    preprocessed_sentences.append(result)

print(preprocessed_sentences)

# %%
print('단어집합:',vocab)

# %%
vocab_sorted = sorted(vocab.items(), key = lambda x:x[1], reverse=True)
print(vocab_sorted)

# %%
# 빈도수에 따른 단어별 정수 mapping

word_to_index = {}
i = 0
for (word, frq) in vocab_sorted:
    if frq > 1: # 1보다 작은 
        i +=1
        word_to_index[word] = i

print(word_to_index)

# %%
# 빈도수가 높은 n개의 단어를 위한 코드 적용

vocab_size = 4

# 인덱스가 4 초과인 단어 제거
# 즉, person, word, keeping 제거 
words_frq = [word for word, index in word_to_index.items() if index >= vocab_size + 1]

for w in words_frq:
    del word_to_index[w]
print(word_to_index)

# %%
word_to_index['OOV'] = len(word_to_index) + 1
print(word_to_index)
