# %% [markdown]
# 1. 순전파(Foward Propagation)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 할성화 함수, 은닉층의 수, 각 은닉층의 뉴런 수 등 DL 모델 설계완료 후 입력층, 은닉층을 지나며 각 층에서의 가중치와 함께 연산되며 출력층으로 향함

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
! pip install tensorflow

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

model = Sequential()

# input = 3, output = 2
model.add(Dense(2,input_dim=3, activation='softmax')) # suppose the softmax reg

# %%
model.summary() # 3 * 2 + 2 = 8

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# another code for NN

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

model = Sequential()

model.add(Dense(8, input_dim=4, activation = 'relu'))
model.add(Dense(8, activation = 'relu'))
model.add(Dense(3, activation = 'softmax'))

# %%
model.summary()
